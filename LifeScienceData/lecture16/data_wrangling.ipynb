# %% [markdown]
# ### Data wrangling without loss
#
# Inspect the “patients_lab_results_messy.csv” dataset
#
# What is wrong with the dataset? Look for e.g.
# - Inconsistent labelling
# - Inconsistent casing
# - Missing values
#
# Fix the issues without loosing any data!
#
# Discuss the reversibility of your steps and think about how you can make sure that you did not loose any data!

# %%
import pandas as pd

df = pd.read_csv("patients_results_messy.csv")
df
# Out:
#   Patient_ID  Visit Date   age  Gender Blood Pressure (mmHg)  Chol (mg_dl)  \
# 0       P001  2021-01-03  34.0    Male                120/80         180.0
# 1       P002   2021/1/05  45.0  FEMALE                135/90         210.0
# 2       P003  03-01-2021  29.0    male                115/75         190.0
# 3       p004  2021.01.04  52.0       F                140/95         220.0
# 4       P005  2021-01-06  33.0       M                118/78         185.0
# 5       P006  2021-01-06  33.0       M                118/78         185.0
# 6       P007  2021/01/07   NaN    Male                125/82         200.0
# 7       P008  2021-01-08  46.0  Female                130/85         195.0
# 8       P009  2021-01-09  50.0  female                128/84           NaN
# 9       P010  2021-01-10  41.0    MALE                132/88         210.0
#
#    glucose            Notes
# 0       95         baseline
# 1      NaN                -
# 2       88          recheck
# 3  missing      new patient
# 4       89           repeat
# 5       89           repeat
# 6   ninety  typo in glucose
# 7      100         baseline
# 8       92                -
# 9       97        follow-up

# %% [markdown]
# Clean up column names using string methods:

# %%
df.columns = df.columns.str.lower().str.replace('[^a-z0-9]+', '_', regex=True).str.strip('_')
df
# Out:
#   patient_id  visit_date   age  gender blood_pressure_mmhg  chol_mg_dl  \
# 0       P001  2021-01-03  34.0    Male              120/80       180.0
# 1       P002   2021/1/05  45.0  FEMALE              135/90       210.0
# 2       P003  03-01-2021  29.0    male              115/75       190.0
# 3       p004  2021.01.04  52.0       F              140/95       220.0
# 4       P005  2021-01-06  33.0       M              118/78       185.0
# 5       P006  2021-01-06  33.0       M              118/78       185.0
# 6       P007  2021/01/07   NaN    Male              125/82       200.0
# 7       P008  2021-01-08  46.0  Female              130/85       195.0
# 8       P009  2021-01-09  50.0  female              128/84         NaN
# 9       P010  2021-01-10  41.0    MALE              132/88       210.0
#
#    glucose            notes
# 0       95         baseline
# 1      NaN                -
# 2       88          recheck
# 3  missing      new patient
# 4       89           repeat
# 5       89           repeat
# 6   ninety  typo in glucose
# 7      100         baseline
# 8       92                -
# 9       97        follow-up

# %% [markdown]
# Split blood pressure values into two columns, using the string method split():

# %%
df[['systolic', 'diastolic']] = df['blood_pressure_mmhg'].str.split('/', expand=True)
df
# Out:
#   patient_id  visit_date   age  gender blood_pressure_mmhg  chol_mg_dl  \
# 0       P001  2021-01-03  34.0    Male              120/80       180.0
# 1       P002   2021/1/05  45.0  FEMALE              135/90       210.0
# 2       P003  03-01-2021  29.0    male              115/75       190.0
# 3       p004  2021.01.04  52.0       F              140/95       220.0
# 4       P005  2021-01-06  33.0       M              118/78       185.0
# 5       P006  2021-01-06  33.0       M              118/78       185.0
# 6       P007  2021/01/07   NaN    Male              125/82       200.0
# 7       P008  2021-01-08  46.0  Female              130/85       195.0
# 8       P009  2021-01-09  50.0  female              128/84         NaN
# 9       P010  2021-01-10  41.0    MALE              132/88       210.0
#
#    glucose            notes systolic diastolic
# 0       95         baseline      120        80
# 1      NaN                -      135        90
# 2       88          recheck      115        75
# 3  missing      new patient      140        95
# 4       89           repeat      118        78
# 5       89           repeat      118        78
# 6   ninety  typo in glucose      125        82
# 7      100         baseline      130        85
# 8       92                -      128        84
# 9       97        follow-up      132        88

# %%
df.systolic = df.systolic.apply(pd.to_numeric)
df.diastolic = df.diastolic.apply(pd.to_numeric)
df
# Out:
#   patient_id  visit_date   age  gender blood_pressure_mmhg  chol_mg_dl  \
# 0       P001  2021-01-03  34.0    Male              120/80       180.0
# 1       P002   2021/1/05  45.0  FEMALE              135/90       210.0
# 2       P003  03-01-2021  29.0    male              115/75       190.0
# 3       p004  2021.01.04  52.0       F              140/95       220.0
# 4       P005  2021-01-06  33.0       M              118/78       185.0
# 5       P006  2021-01-06  33.0       M              118/78       185.0
# 6       P007  2021/01/07   NaN    Male              125/82       200.0
# 7       P008  2021-01-08  46.0  Female              130/85       195.0
# 8       P009  2021-01-09  50.0  female              128/84         NaN
# 9       P010  2021-01-10  41.0    MALE              132/88       210.0
#
#    glucose            notes  systolic  diastolic
# 0       95         baseline       120         80
# 1      NaN                -       135         90
# 2       88          recheck       115         75
# 3  missing      new patient       140         95
# 4       89           repeat       118         78
# 5       89           repeat       118         78
# 6   ninety  typo in glucose       125         82
# 7      100         baseline       130         85
# 8       92                -       128         84
# 9       97        follow-up       132         88

# %% [markdown]
# Convert glucose values:

# %%
df['glucose'] = pd.to_numeric(df['glucose'], errors="coerce") # avoids crashing if wrong types are parsed
df
# Out:
#   patient_id  visit_date   age  gender blood_pressure_mmhg  chol_mg_dl  \
# 0       P001  2021-01-03  34.0    Male              120/80       180.0
# 1       P002   2021/1/05  45.0  FEMALE              135/90       210.0
# 2       P003  03-01-2021  29.0    male              115/75       190.0
# 3       p004  2021.01.04  52.0       F              140/95       220.0
# 4       P005  2021-01-06  33.0       M              118/78       185.0
# 5       P006  2021-01-06  33.0       M              118/78       185.0
# 6       P007  2021/01/07   NaN    Male              125/82       200.0
# 7       P008  2021-01-08  46.0  Female              130/85       195.0
# 8       P009  2021-01-09  50.0  female              128/84         NaN
# 9       P010  2021-01-10  41.0    MALE              132/88       210.0
#
#    glucose            notes  systolic  diastolic
# 0     95.0         baseline       120         80
# 1      NaN                -       135         90
# 2     88.0          recheck       115         75
# 3      NaN      new patient       140         95
# 4     89.0           repeat       118         78
# 5     89.0           repeat       118         78
# 6      NaN  typo in glucose       125         82
# 7    100.0         baseline       130         85
# 8     92.0                -       128         84
# 9     97.0        follow-up       132         88

# %% [markdown]
# Standardize gender:

# %%
df['gender'] = df['gender'].str.upper().map({'MALE': 'M', 'FEMALE': 'F', 'M': 'M', 'F': 'F'})
df
# Out:
#   patient_id  visit_date   age gender blood_pressure_mmhg  chol_mg_dl  \
# 0       P001  2021-01-03  34.0      M              120/80       180.0
# 1       P002   2021/1/05  45.0      F              135/90       210.0
# 2       P003  03-01-2021  29.0      M              115/75       190.0
# 3       p004  2021.01.04  52.0      F              140/95       220.0
# 4       P005  2021-01-06  33.0      M              118/78       185.0
# 5       P006  2021-01-06  33.0      M              118/78       185.0
# 6       P007  2021/01/07   NaN      M              125/82       200.0
# 7       P008  2021-01-08  46.0      F              130/85       195.0
# 8       P009  2021-01-09  50.0      F              128/84         NaN
# 9       P010  2021-01-10  41.0      M              132/88       210.0
#
#    glucose            notes  systolic  diastolic
# 0     95.0         baseline       120         80
# 1      NaN                -       135         90
# 2     88.0          recheck       115         75
# 3      NaN      new patient       140         95
# 4     89.0           repeat       118         78
# 5     89.0           repeat       118         78
# 6      NaN  typo in glucose       125         82
# 7    100.0         baseline       130         85
# 8     92.0                -       128         84
# 9     97.0        follow-up       132         88

# %% [markdown]
# Parse dates to standard format:

# %%
# standardize visit_date
df['visit_date'] = (
    df['visit_date']
    .str.replace(r'[./]', '-', regex=True)  # unify separators
    .str.strip()
)

df['visit_date_clean'] = pd.to_datetime(df['visit_date'], errors='coerce')
df
# Out:
#   patient_id  visit_date   age gender blood_pressure_mmhg  chol_mg_dl  \
# 0       P001  2021-01-03  34.0      M              120/80       180.0
# 1       P002   2021-1-05  45.0      F              135/90       210.0
# 2       P003  03-01-2021  29.0      M              115/75       190.0
# 3       p004  2021-01-04  52.0      F              140/95       220.0
# 4       P005  2021-01-06  33.0      M              118/78       185.0
# 5       P006  2021-01-06  33.0      M              118/78       185.0
# 6       P007  2021-01-07   NaN      M              125/82       200.0
# 7       P008  2021-01-08  46.0      F              130/85       195.0
# 8       P009  2021-01-09  50.0      F              128/84         NaN
# 9       P010  2021-01-10  41.0      M              132/88       210.0
#
#    glucose            notes  systolic  diastolic visit_date_clean
# 0     95.0         baseline       120         80       2021-01-03
# 1      NaN                -       135         90       2021-01-05
# 2     88.0          recheck       115         75              NaT
# 3      NaN      new patient       140         95       2021-01-04
# 4     89.0           repeat       118         78       2021-01-06
# 5     89.0           repeat       118         78       2021-01-06
# 6      NaN  typo in glucose       125         82       2021-01-07
# 7    100.0         baseline       130         85       2021-01-08
# 8     92.0                -       128         84       2021-01-09
# 9     97.0        follow-up       132         88       2021-01-10

# %% [markdown]
# Fill or flag missing data (no deletions) in some of the columns:

# %% [markdown]
# Further cleanup: patient_id!

# %%
df.patient_id = df.patient_id.str.upper()
df
# Out:
#   patient_id  visit_date   age gender blood_pressure_mmhg  chol_mg_dl  \
# 0       P001  2021-01-03  34.0      M              120/80       180.0
# 1       P002   2021-1-05  45.0      F              135/90       210.0
# 2       P003  03-01-2021  29.0      M              115/75       190.0
# 3       P004  2021-01-04  52.0      F              140/95       220.0
# 4       P005  2021-01-06  33.0      M              118/78       185.0
# 5       P006  2021-01-06  33.0      M              118/78       185.0
# 6       P007  2021-01-07   NaN      M              125/82       200.0
# 7       P008  2021-01-08  46.0      F              130/85       195.0
# 8       P009  2021-01-09  50.0      F              128/84         NaN
# 9       P010  2021-01-10  41.0      M              132/88       210.0
#
#    glucose            notes  systolic  diastolic visit_date_clean
# 0     95.0         baseline       120         80       2021-01-03
# 1      NaN                -       135         90       2021-01-05
# 2     88.0          recheck       115         75              NaT
# 3      NaN      new patient       140         95       2021-01-04
# 4     89.0           repeat       118         78       2021-01-06
# 5     89.0           repeat       118         78       2021-01-06
# 6      NaN  typo in glucose       125         82       2021-01-07
# 7    100.0         baseline       130         85       2021-01-08
# 8     92.0                -       128         84       2021-01-09
# 9     97.0        follow-up       132         88       2021-01-10

# %% [markdown]
# Convert type in systolic and diastolic pressure columns (pd.to_numeric)

# %% [markdown]
# Add the extended patient list and the patients info.

# %%
df_extension = pd.read_csv('patient_list_extended.csv')
df_2merge = pd.read_csv('patients_info.csv')

# %%
df_extended = pd.concat([df, df_extension], ignore_index=True)

# %%
df_complete = pd.merge(df_extended, df_2merge, on='patient_id', how='outer')
df_complete.head()
# Out:
#   patient_id  visit_date   age gender blood_pressure_mmhg  chol_mg_dl  \
# 0       P001  2021-01-03  34.0      M              120/80       180.0
# 1       P002   2021-1-05  45.0      F              135/90       210.0
# 2       P003  03-01-2021  29.0      M              115/75       190.0
# 3       P004  2021-01-04  52.0      F              140/95       220.0
# 4       P005  2021-01-06  33.0      M              118/78       185.0
#
#    glucose        notes  systolic  diastolic visit_date_clean   bmi  smoker
# 0     95.0     baseline       120         80       2021-01-03  24.5  No
# 1      NaN            -       135         90       2021-01-05  27.2     Yes
# 2     88.0      recheck       115         75              NaT  25.0      No
# 3      NaN  new patient       140         95       2021-01-04  31.0     Yes
# 4     89.0       repeat       118         78       2021-01-06  26.4      No

# %%
df_complete2 = df_extended.join(df_2merge, on='patient_id', how='outer')
df_complete2.head()

# %%
print(df.shape)
print(df_extension.shape)
print(df_extended.shape)
print(df_2merge.shape)
print(df_complete.shape)
# Out:
# (10, 11)
# (42, 10)
# (52, 11)
# (38, 3)
# (56, 13)

# %%
df_complete.to_csv('patient_list_complete.csv', index=False)

# %%
df_complete.isna().sum()
# Out:
# patient_id              0
# visit_date              0
# age                     9
# gender                  0
# blood_pressure_mmhg     0
# chol_mg_dl              7
# glucose                15
# notes                  21
# systolic                0
# diastolic               0
# visit_date_clean       47
# bmi                    18
# smoker                 24
# dtype: int64

# %%
df_complete['is_age_missing'] = df_complete.age.isna()
df_complete
# Out:
#    patient_id  visit_date    age gender blood_pressure_mmhg  chol_mg_dl  \
# 0        P001  2021-01-03   34.0      M              120/80       180.0
# 1        P002   2021-1-05   45.0      F              135/90       210.0
# 2        P003  03-01-2021   29.0      M              115/75       190.0
# 3        P004  2021-01-04   52.0      F              140/95       220.0
# 4        P005  2021-01-06   33.0      M              118/78       185.0
# 5        P006  2021-01-06   33.0      M              118/78       185.0
# 6        P007  2021-01-07    NaN      M              125/82       200.0
# 7        P008  2021-01-08   46.0      F              130/85       195.0
# 8        P009  2021-01-09   50.0      F              128/84         NaN
# 9        P010  2021-01-10   41.0      M              132/88       210.0
# 10       P011  2021-01-03   33.0      M              110/81       177.0
# 11       P012   2021/1/05   55.0      F              135/92         NaN
# 12       P013   2021/1/05   69.0      M              125/75       190.0
# 13       P014  2021.01.04   42.0      F              130/91       228.0
# 14       P015  2021-01-06   43.0      M              118/79       134.0
# 15       P016  2021-01-06   63.0      M              133/78       188.0
# 16       P017  2021/01/07    NaN      M              122/82       210.0
# 17       P018  2021-01-08    NaN      F              134/86       192.0
# 18       P018  2021-01-08    NaN      F              134/86       192.0
# 19       P019  2021-01-09   44.0      F              128/83         NaN
# 20       P020  2021-01-10   41.0      M              112/78       210.0
# 21       P021  2021-01-03   21.0      M              120/83         NaN
# 22       P021  2021-01-03   21.0      M              120/83         NaN
# 23       P022  2021/01/07   66.0      F              132/90       211.0
# 24       P022  2021/01/07   66.0      F              132/90       211.0
# 25       P023  2021/01/07   29.0      M              131/75       149.0
# 26       P023  2021/01/07   29.0      M              131/75       149.0
# 27       P024  2021.01.04   51.0      F              130/95       228.0
# 28       P024  2021.01.04   51.0      F              130/95       228.0
# 29       P025  2021-01-06   31.0      D              128/83       122.0
# 30       P026  2021-01-06   33.0      M              138/88       186.0
# 31       P027  2021/01/07    NaN      M              125/84         NaN
# 32       P028  2021-01-08   47.0      F              140/85       195.0
# 33       P029  2021-01-06   58.0      F              145/89       126.0
# 34       P030  2021-01-10   48.0      M              137/88       240.0
# 35       P031  2021-01-06   12.0      M              122/80       110.0
# 36       P032   2021/1/05   45.0      F              115/90       213.0
# 37       P033  2021-01-06    NaN      M              123/86       194.0
# 38       P034  2021.01.04   74.0      F              141/95       210.0
# 39       P035  2021-01-08   37.0      M              123/85       175.0
# 40       P036  2021-01-06    NaN      M              118/83       165.0
# 41       P037  2021/01/07    NaN      M              127/84       140.0
# 42       P038  2021-01-08   26.0      D              131/85       150.0
# 43       P039  2021-01-09   57.0      F              133/87       134.0
# 44       P040  2021-01-10   41.0      M              132/82       170.0
# 45       P041  2021-01-03   38.0      M              123/82       150.0
# 46       P042   2021/1/05   43.0      F              135/91       213.0
# 47       P043  03-01-2021   69.0      M              155/95       170.0
# 48       P044  2021.01.08   42.0      F              130/78       210.0
# 49       P044  2021.01.08   42.0      F              130/78       210.0
# 50       P045  2021-01-06   13.0      M              112/75       185.0
# 51       P046  2021-01-06  133.0      D              113/78       135.0
# 52       P047  2021/01/07    NaN      M              115/82       150.0
# 53       P048  2021-01-08   48.0      F              131/85       145.0
# 54       P049  2021-01-11   56.0      F              129/83         NaN
# 55       P050  2021-01-13   42.0      M              133/87       190.0
#
#     glucose            notes  systolic  diastolic visit_date_clean   bmi  \
# 0      95.0         baseline       120         80       2021-01-03  24.5
# 1       NaN                -       135         90       2021-01-05  27.2
# 2      88.0          recheck       115         75              NaT  25.0
# 3       NaN      new patient       140         95       2021-01-04  31.0
# 4      89.0           repeat       118         78       2021-01-06  26.4
# 5      89.0           repeat       118         78       2021-01-06  22.5
# 6       NaN  typo in glucose       125         82       2021-01-07  24.2
# 7     100.0         baseline       130         85       2021-01-08  23.0
# 8      92.0                -       128         84       2021-01-09  27.0
# 9      97.0        follow-up       132         88       2021-01-10  22.4
# 10     85.0         baseline       110         81              NaT  22.5
# 11      NaN                -       135         92              NaT  26.2
# 12     82.0              NaN       125         75              NaT  24.0
# 13    125.0      new patient       130         91              NaT  21.0
# 14    111.0              NaN       118         79              NaT  25.4
# 15     99.0           repeat       133         78              NaT  22.5
# 16     76.0      new patient       122         82              NaT  21.2
# 17    130.0              NaN       134         86              NaT   NaN
# 18    130.0              NaN       134         86              NaT   NaN
# 19     99.0                -       128         83              NaT   NaN
# 20     94.0        follow-up       112         78              NaT   NaN
# 21     85.0              NaN       120         83              NaT  24.0
# 22     85.0              NaN       120         83              NaT  24.0
# 23      NaN                -       132         90              NaT  25.7
# 24      NaN                -       132         90              NaT  25.4
# 25      NaN              NaN       131         75              NaT  22.2
# 26      NaN              NaN       131         75              NaT  25.2
# 27     76.0              NaN       130         95              NaT  22.4
# 28     76.0              NaN       130         95              NaT  21.4
# 29    128.0              NaN       128         83              NaT  22.7
# 30     84.0              NaN       138         88              NaT  24.1
# 31    122.0              NaN       125         84              NaT  22.1
# 32    170.0         baseline       140         85              NaT  21.0
# 33     72.0                -       145         89              NaT  27.0
# 34      NaN        follow-up       137         88              NaT  22.4
# 35      NaN              NaN       122         80              NaT  22.5
# 36      NaN                -       115         90              NaT  26.2
# 37    118.0          recheck       123         86              NaT   NaN
# 38    100.0          recheck       141         95              NaT   NaN
# 39     79.0              NaN       123         85              NaT  22.7
# 40     85.0          recheck       118         83              NaT   NaN
# 41   1200.0      new patient       127         84              NaT  23.1
# 42    100.0         baseline       131         85              NaT  22.0
# 43      NaN                -       133         87              NaT  28.0
# 44     92.0        follow-up       132         82              NaT  31.4
# 45     84.0              NaN       123         82              NaT   NaN
# 46      NaN                -       135         91              NaT   NaN
# 47     88.0              NaN       155         95              NaT   NaN
# 48      NaN              NaN       130         78              NaT   NaN
# 49      NaN              NaN       130         78              NaT   NaN
# 50     75.0      new patient       112         75              NaT   NaN
# 51     89.0           repeat       113         78              NaT   NaN
# 52    111.0              NaN       115         82              NaT   NaN
# 53    140.0              NaN       131         85              NaT   NaN
# 54    172.0                -       129         83              NaT   NaN
# 55     88.0        follow-up       133         87              NaT   NaN
#
#     smoker  is_age_missing
# 0   No               False
# 1      Yes           False
# 2       No           False
# 3      Yes           False
# 4       No           False
# 5   No               False
# 6      Yes            True
# 7       No           False
# 8       No           False
# 9       No           False
# 10  No               False
# 11     NaN           False
# 12      No           False
# 13     NaN           False
# 14      No           False
# 15  No               False
# 16     Yes            True
# 17     NaN            True
# 18     NaN            True
# 19     NaN           False
# 20     NaN           False
# 21     NaN           False
# 22     Yes           False
# 23      No           False
# 24     NaN           False
# 25  No               False
# 26  No               False
# 27     Yes           False
# 28     Yes           False
# 29  No               False
# 30     NaN           False
# 31      No            True
# 32     Yes           False
# 33      No           False
# 34      No           False
# 35                   False
# 36     Yes           False
# 37     NaN            True
# 38     NaN           False
# 39  No               False
# 40     NaN            True
# 41      No            True
# 42     Yes           False
# 43     NaN           False
# 44      No           False
# 45     NaN           False
# 46     NaN           False
# 47     NaN           False
# 48     NaN           False
# 49     NaN           False
# 50     NaN           False
# 51     NaN           False
# 52     NaN            True
# 53     NaN           False
# 54     NaN           False
# 55     NaN           False

# %%
df_dropna_smokers = df_complete.dropna(subset='smoker')
df_dropna_smokers
# Out:
#    patient_id  visit_date   age gender blood_pressure_mmhg  chol_mg_dl  \
# 0        P001  2021-01-03  34.0      M              120/80       180.0
# 1        P002   2021-1-05  45.0      F              135/90       210.0
# 2        P003  03-01-2021  29.0      M              115/75       190.0
# 3        P004  2021-01-04  52.0      F              140/95       220.0
# 4        P005  2021-01-06  33.0      M              118/78       185.0
# 5        P006  2021-01-06  33.0      M              118/78       185.0
# 6        P007  2021-01-07   NaN      M              125/82       200.0
# 7        P008  2021-01-08  46.0      F              130/85       195.0
# 8        P009  2021-01-09  50.0      F              128/84         NaN
# 9        P010  2021-01-10  41.0      M              132/88       210.0
# 10       P011  2021-01-03  33.0      M              110/81       177.0
# 12       P013   2021/1/05  69.0      M              125/75       190.0
# 14       P015  2021-01-06  43.0      M              118/79       134.0
# 15       P016  2021-01-06  63.0      M              133/78       188.0
# 16       P017  2021/01/07   NaN      M              122/82       210.0
# 22       P021  2021-01-03  21.0      M              120/83         NaN
# 23       P022  2021/01/07  66.0      F              132/90       211.0
# 25       P023  2021/01/07  29.0      M              131/75       149.0
# 26       P023  2021/01/07  29.0      M              131/75       149.0
# 27       P024  2021.01.04  51.0      F              130/95       228.0
# 28       P024  2021.01.04  51.0      F              130/95       228.0
# 29       P025  2021-01-06  31.0      D              128/83       122.0
# 31       P027  2021/01/07   NaN      M              125/84         NaN
# 32       P028  2021-01-08  47.0      F              140/85       195.0
# 33       P029  2021-01-06  58.0      F              145/89       126.0
# 34       P030  2021-01-10  48.0      M              137/88       240.0
# 35       P031  2021-01-06  12.0      M              122/80       110.0
# 36       P032   2021/1/05  45.0      F              115/90       213.0
# 39       P035  2021-01-08  37.0      M              123/85       175.0
# 41       P037  2021/01/07   NaN      M              127/84       140.0
# 42       P038  2021-01-08  26.0      D              131/85       150.0
# 44       P040  2021-01-10  41.0      M              132/82       170.0
#
#     glucose            notes  systolic  diastolic visit_date_clean   bmi  \
# 0      95.0         baseline       120         80       2021-01-03  24.5
# 1       NaN                -       135         90       2021-01-05  27.2
# 2      88.0          recheck       115         75              NaT  25.0
# 3       NaN      new patient       140         95       2021-01-04  31.0
# 4      89.0           repeat       118         78       2021-01-06  26.4
# 5      89.0           repeat       118         78       2021-01-06  22.5
# 6       NaN  typo in glucose       125         82       2021-01-07  24.2
# 7     100.0         baseline       130         85       2021-01-08  23.0
# 8      92.0                -       128         84       2021-01-09  27.0
# 9      97.0        follow-up       132         88       2021-01-10  22.4
# 10     85.0         baseline       110         81              NaT  22.5
# 12     82.0              NaN       125         75              NaT  24.0
# 14    111.0              NaN       118         79              NaT  25.4
# 15     99.0           repeat       133         78              NaT  22.5
# 16     76.0      new patient       122         82              NaT  21.2
# 22     85.0              NaN       120         83              NaT  24.0
# 23      NaN                -       132         90              NaT  25.7
# 25      NaN              NaN       131         75              NaT  22.2
# 26      NaN              NaN       131         75              NaT  25.2
# 27     76.0              NaN       130         95              NaT  22.4
# 28     76.0              NaN       130         95              NaT  21.4
# 29    128.0              NaN       128         83              NaT  22.7
# 31    122.0              NaN       125         84              NaT  22.1
# 32    170.0         baseline       140         85              NaT  21.0
# 33     72.0                -       145         89              NaT  27.0
# 34      NaN        follow-up       137         88              NaT  22.4
# 35      NaN              NaN       122         80              NaT  22.5
# 36      NaN                -       115         90              NaT  26.2
# 39     79.0              NaN       123         85              NaT  22.7
# 41   1200.0      new patient       127         84              NaT  23.1
# 42    100.0         baseline       131         85              NaT  22.0
# 44     92.0        follow-up       132         82              NaT  31.4
#
#     smoker  is_age_missing
# 0   No               False
# 1      Yes           False
# 2       No           False
# 3      Yes           False
# 4       No           False
# 5   No               False
# 6      Yes            True
# 7       No           False
# 8       No           False
# 9       No           False
# 10  No               False
# 12      No           False
# 14      No           False
# 15  No               False
# 16     Yes            True
# 22     Yes           False
# 23      No           False
# 25  No               False
# 26  No               False
# 27     Yes           False
# 28     Yes           False
# 29  No               False
# 31      No            True
# 32     Yes           False
# 33      No           False
# 34      No           False
# 35                   False
# 36     Yes           False
# 39  No               False
# 41      No            True
# 42     Yes           False
# 44      No           False

# %%
import seaborn as sns

sns.histplot(df_dropna_smokers['chol_mg_dl'], kde=True)
# Out:
# <Axes: xlabel='chol_mg_dl', ylabel='Count'>

# %%
df_complete.duplicated().sum()
df_complete.duplicated(subset=['age', 'chol_mg_dl']).sum()
# Out:
# np.int64(8)
